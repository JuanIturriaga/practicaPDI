# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from img_basic import *
from img_aux import *

# %%
img = cv.imread("imgs/BANKVID.TIF", cv.IMREAD_GRAYSCALE)
assert img is not None, "Image not found"
print (type(img))
print (img.shape)
plt.imshow(img, 'gray')
# Out:
# <class 'numpy.ndarray'>
# (154, 251)

# %%
face = img[45:75, 190:220]
plt.imshow(face, 'gray')

# %%
plt.plot(img_histogram(face))        
plt.show()

# %%
plt.imshow(img_gray_level_slicing (img.copy(), 130, 180, 50, type = 'zero'), 'gray')

# %%
#mejorando la cara del empleado de la derecha
points = np.array([[130,45],[180,160]])
der = img_contrast_stretching (img.copy(), points)
plt.imshow(der, 'gray')

# %%
plt.imshow(img_gray_level_slicing (img.copy(), 100, 130, 50, type = 'zero'), 'gray')

# %%
#mejorando la cara del empleado de la izquierda
points = np.array([[100,75],[130,210]])
izq = img_contrast_stretching (img.copy(), points)
plt.imshow(izq, 'gray')

# %%
#promediar fotos izq y der
b = np.zeros((img.shape[0], img.shape[1]))
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        b[i,j] = (izq[i,j] * 0.35 + der[i,j] * 0.65) 

plt.imshow(b, 'gray')

# %%
plt.imshow(img, 'gray')
