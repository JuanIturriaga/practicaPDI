# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from img_basic import *

# %%
img = cv.imread("imgs/FETLOCK.TIF", cv.IMREAD_GRAYSCALE)
assert img is not None, "Image not found"
print (type(img))
print (img.shape)
plt.imshow(img, 'gray')
# Out:
# <class 'numpy.ndarray'>
# (370, 297)

# %%
plt.plot(map_contrast(0))
plt.plot(map_contrast(50))
plt.plot(map_contrast(100))  
plt.plot(map_contrast(100,0))  
plt.plot(map_contrast(100,50))  
plt.plot(map_brightness(-50))  
plt.plot(map_brightness(50))  
plt.plot(map_brightness(255))  
plt.show()

# %%
plt.imshow(img_brightness(img.copy(), 100), 'gray')

# %%
plt.imshow(img_contrast(img.copy(), 200 ,20), 'gray')

# %%
c = img.copy()
#img_negative(c)
img_brightness(c,50)
img_contrast(c,50,60)
#img_bitplane(c, 6)
img_mask(c, 0B01100000)
plt.imshow(c, 'gray')

# %%
plt.imshow(img_bitplane(img.copy(), 6), 'gray')

# %%
plt.imshow(img_mask(img.copy(), 0B01100000), 'gray')

# %%
plt.plot(map_bitplane(6))  
plt.plot(map_mask(0B00010000))  
plt.show()

# %%
points = np.array([[20,20],[50,180],[120,30]])
plt.imshow(img_contrast_stretching(img.copy(), points), 'gray')

# %%
plt.plot(map_normal())  
plt.plot(map_gray_level_slicing(20, 50, 100, type='linear'))
plt.plot(map_gray_level_slicing(20, 50, 100, type='zero'))
plt.plot(map_gray_level_slicing(20, 50, 100, type='glow'))
plt.plot(map_gray_level_slicing(20, 50, 100, type='glow_zero'))
plt.show()

# %%
plt.imshow(img_gray_level_slicing(img.copy(), 70, 120, 10, type = 'glow_zero'), 'gray')

# %%
plt.plot(map_normal())  
#plt.plot(map_dynamic_range_compression())
#plt.plot(map_dynamic_range_compression_b(0.3))
plt.plot(map_dynamic_range_compression_b(0.8))
plt.show()

# %%
plt.imshow(img_dynamic_range_compression(img.copy()), 'gray')

# %%
test = img.copy()
img_dynamic_range_compression_b(test,0.6)
img_brightness(test, 60)
img_contrast(test, 100, 20)
plt.imshow(test, 'gray')
